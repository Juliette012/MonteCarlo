# %% [markdown]
# # Comparaison des résultats entre les algorithmes HSP et MCTS
# ### Dartois Juliette
# ### Fauchon Louis-Bastien

# %%
# %pip install matplotlib
import matplotlib.pyplot as plt
# Out:
# ...
#      ---------------------------------------- 0.0/167.0 kB ? eta -:--:--
#      -------------- ------------------------ 61.4/167.0 kB 1.7 MB/s eta 0:00:01
#      -------------------------------------- 167.0/167.0 kB 2.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ---------------------------------------- 60.8/60.8 kB ? eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    --------------- ------------------------ 3.1/7.8 MB 99.8 MB/s eta 0:00:01
#    -------------------------------- ------- 6.4/7.8 MB 100.9 MB/s eta 0:00:01
#    ---------------------------------------- 7.8/7.8 MB 83.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/218.3 kB ? eta -:--:--
#    --------------------------------------- 218.3/218.3 kB 13.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
# ...

# %%
# Nombre d'étapes 
HSP_et = [6,10,6,12,9]
MCTS_et = [6,11,7,20,12]

# Temps d'exéc
HSP_tmp = [4,4,5,5,5]
MCTS_tmp = [5,5,4,4,4]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Graphique d'étapes
ax1.plot(HSP_et, label='HSP', color='blue')
ax1.plot(MCTS_et, label='MCTS', color='red')
ax1.set_xlabel('difficulté du problème')
ax1.set_ylabel('Nombre d\'étapes')
plt.ylabel('Nombre d\'étapes')
ax1.set_xticks(range(5))
ax1.set_xticklabels(range(1, 6))
ax1.set_title('Blocks problem')
ax1.legend()

# Graphique de temps d'exécution
ax2.plot(HSP_tmp, label='HSP', color='blue')
ax2.plot(MCTS_tmp, label='MCTS', color='red')
ax2.set_xlabel('difficulté du problème')
plt.ylabel('Temps d\'exécution')
ax2.set_xticks(range(5))
ax2.set_xticklabels(range(1, 6))
ax2.set_title('Blocks problem')
ax2.legend()

# Affichage des graphes
plt.show()

# %%
# Nombre d'étapes 
HSP_et = [11,17,23,29,35]
MCTS_et = [15,22,27,39,47]

# Temps d'exéc
HSP_tmp = [6,8,24,92,430]
MCTS_tmp = [4,4,4,5,5]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Graphique d'étapes
ax1.plot(HSP_et, label='HSP', color='blue')
ax1.plot(MCTS_et, label='MCTS', color='red')
ax1.set_xlabel('difficulté du problème')
ax1.set_ylabel('Nombre d\'étapes')
ax1.set_xticks(range(5))
ax1.set_xticklabels(range(1, 6))
ax1.set_title('Gripper problem')
ax1.legend()

# Graphique de temps d'exécution
ax2.plot(HSP_tmp, label='HSP', color='blue')
ax2.plot(MCTS_tmp, label='MCTS', color='red')
ax2.set_xlabel('difficulté du problème')
ax2.set_ylabel('Temps d\'exécution')
ax2.set_xticks(range(5))
ax2.set_xticklabels(range(1, 6))
ax2.set_title('Gripper problem')
ax2.legend()

# Affichage des graphes
plt.show()

# %%
# Nombre d'étapes 
HSP_et = [10,15,29]
MCTS_et = [15,24,69]

# Temps d'exéc
HSP_tmp = [8,11,15]
MCTS_tmp = [6,9,10]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Graphique d'étapes
ax1.plot(HSP_et, label='HSP', color='blue')
ax1.plot(MCTS_et, label='MCTS', color='red')
ax1.set_xlabel('difficulté du problème')
plt.ylabel('Nombre d\'étapes')
ax1.set_ylabel('Nombre d\'étapes')
ax1.set_xticks(range(3))
ax1.set_xticklabels(range(1, 4))
ax1.set_title('Depot problem')
ax1.legend()

# Graphique de temps d'exécution
ax2.plot(HSP_tmp, label='HSP', color='blue')
ax2.plot(MCTS_tmp, label='MCTS', color='red')
ax2.set_xlabel('difficulté du problème')
plt.ylabel('Temps d\'exécution')
ax2.set_xticks(range(3))
ax2.set_xticklabels(range(1, 4))
ax2.set_title('Depot problem')
ax2.legend()

# Affichage des graphes
plt.show()

# %%
# Nombre d'étapes 
HSP_et = [23,23]
MCTS_et = [45,45]

# Temps d'exéc
HSP_tmp = [240,240]
MCTS_tmp = [15,15]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Graphique d'étapes
ax1.plot(HSP_et, label='HSP', color='blue')
ax1.plot(MCTS_et, label='MCTS', color='red')
ax1.set_xlabel('difficulté du problème')
ax1.set_ylabel('Nombre d\'étapes')
ax1.set_xticks(range(2))
ax1.set_xticklabels(range(2, 2))
ax1.set_title('Logistic problem')
ax1.legend()

# Graphique de temps d'exécution
ax2.plot(HSP_tmp, label='HSP', color='blue')
ax2.plot(MCTS_tmp, label='MCTS', color='red')
ax2.set_xlabel('difficulté du problème')
ax2.set_ylabel('Temps d\'exécution')
ax2.set_xticks(range(2))
ax2.set_xticklabels(range(2, 2))
ax2.set_title('Logistic problem')
ax2.legend()

# Affichage des graphes
plt.show()

# %% [markdown]
# ## Conclusion
#
# On peut observer sur les graphes de gauche que les MCTS mettent toujours plus de mouvements que l'HSP pour obtenir l'état goal, ceci est du au fait que le MCTS autorise les actions inutiles et les boucles.
#
# Pour les comparaisons des temps d'execution je ne pense pas que les données soient pertinentes et intéresantes, cela étant fortement corrélés à l'ordinateur qui exécute les commandes
